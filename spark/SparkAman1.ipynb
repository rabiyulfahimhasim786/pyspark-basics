# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
from pyspark.sql.types import ArrayType, DoubleType, BooleanType
from pyspark.sql.functions import col,array_contains

# %%
sparkSession --> DataFrame
SparkContext --> RDD

# %%
spark = SparkSession.builder.appName('spark1').getOrCreate()




# dataframe2.printSchema()
   
# Using delimiter
# dataframe3 = spark.read.options(header='True', delimiter=',') \
#               .csv("/FileStore/tables/zipcodes-2.csv")
# dataframe3.printSchema()

# %%
df = spark.read.options(header='True', delimiter=',').csv("/FileStore/tables/employees.csv")
df.show()
# Out:
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |First Name|Gender|Start Date|Last Login Time|Salary|Bonus %|Senior Management|                Team|
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |   Douglas|  Male|  8/6/1993|       12:42 PM| 97308|  6.945|             true|           Marketing|
# |    Thomas|  Male| 3/31/1996|        6:53 AM| 61933|   4.17|             true|                null|
# |     Maria|Female| 4/23/1993|       11:17 AM|130590| 11.858|            false|             Finance|
# |     Jerry|  Male|  3/4/2005|        1:00 PM|138705|   9.34|             true|             Finance|
# |     Larry|  Male| 1/24/1998|        4:47 PM|101004|  1.389|             true|     Client Services|
# |    Dennis|  Male| 4/18/1987|        1:35 AM|115163| 10.125|            false|               Legal|
# ...

# %%
dataframe = spark.read.csv("/FileStore/tables/employees.csv")
dataframe.printSchema()
dataframe.show()
# Out:
# root
#  |-- _c0: string (nullable = true)
#  |-- _c1: string (nullable = true)
#  |-- _c2: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)
#  |-- _c7: string (nullable = true)
#
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |       _c0|   _c1|       _c2|            _c3|   _c4|    _c5|              _c6|                 _c7|
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |First Name|Gender|Start Date|Last Login Time|Salary|Bonus %|Senior Management|                Team|
# |   Douglas|  Male|  8/6/1993|       12:42 PM| 97308|  6.945|             true|           Marketing|
# |    Thomas|  Male| 3/31/1996|        6:53 AM| 61933|   4.17|             true|                null|
# ...

# %%
dataframe2 = spark.read.option("header",True).csv("/FileStore/tables/employees.csv")
dataframe2.printSchema()
dataframe2.show()
# Out:
# root
#  |-- First Name: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Last Login Time: string (nullable = true)
#  |-- Salary: string (nullable = true)
#  |-- Bonus %: string (nullable = true)
#  |-- Senior Management: string (nullable = true)
#  |-- Team: string (nullable = true)
#
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |First Name|Gender|Start Date|Last Login Time|Salary|Bonus %|Senior Management|                Team|
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |   Douglas|  Male|  8/6/1993|       12:42 PM| 97308|  6.945|             true|           Marketing|
# |    Thomas|  Male| 3/31/1996|        6:53 AM| 61933|   4.17|             true|                null|
# |     Maria|Female| 4/23/1993|       11:17 AM|130590| 11.858|            false|             Finance|
# ...

# %%
dataframe3 = spark.read.options(header='True', delimiter='\t') \
              .csv("/FileStore/tables/zipcodes-2.csv")

# %%
df2 = spark.read.csv('/FileStore/tables/employees.csv', sep=',',
                         inferSchema=True, header=True)
df2 = spark.read.option("header",'True').option("inferSchema","True").csv("/FileStore/tables/employees.csv")

# %%
df2.printSchema()
# Out:
# root
#  |-- First Name: string (nullable = true)
#  |-- Gender: string (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Last Login Time: string (nullable = true)
#  |-- Salary: integer (nullable = true)
#  |-- Bonus %: double (nullable = true)
#  |-- Senior Management: boolean (nullable = true)
#  |-- Team: string (nullable = true)

# %%
df = spark.read.option("header","true").format("csv").load("/FileStore/tables/employees.csv")

# %%
path = ['FileStore/tables/employees.csv',
        'FileStore/tables/employees.csv']
 
files = spark.read.csv(path, sep=',',
                       inferSchema=True, header=True)

# %%
file2 = spark.read.csv('/content/*.csv', sep=',',
                    inferSchema=True, header=True)

# %%
df.printSchema()
# Out:
# Out[9]: 2000

# %%
df #return DataFrame
df.show() #return first 20 rows 
display(df)#return 1000 records from dataframe
# Out:
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |First Name|Gender|Start Date|Last Login Time|Salary|Bonus %|Senior Management|                Team|
# +----------+------+----------+---------------+------+-------+-----------------+--------------------+
# |   Douglas|  Male|  8/6/1993|       12:42 PM| 97308|  6.945|             true|           Marketing|
# |    Thomas|  Male| 3/31/1996|        6:53 AM| 61933|   4.17|             true|                null|
# |     Maria|Female| 4/23/1993|       11:17 AM|130590| 11.858|            false|             Finance|
# |     Jerry|  Male|  3/4/2005|        1:00 PM|138705|   9.34|             true|             Finance|
# |     Larry|  Male| 1/24/1998|        4:47 PM|101004|  1.389|             true|     Client Services|
# |    Dennis|  Male| 4/18/1987|        1:35 AM|115163| 10.125|            false|               Legal|
# ...

# %%
from pyspark.sql.types import  StructType , StructField , StringType , IntegerType , BooleanType , FloatType
myschema = StructType([StructField('First Name',StringType() , True),
                       StructField('Gender',StringType() , True),
                      StructField('Start Date',StringType() , True),
                      StructField('Last Login Time',StringType() , True),
                      StructField('Salary', IntegerType() , True),
                      StructField('Bonus %', FloatType() , True),
                      StructField('Senior Management',BooleanType() , True),
                      StructField('Team',StringType() , True)])
df = spark.read.option("header","true").format("csv").schema(myschema).load("/FileStore/tables/employees.csv")

# %%
csv--> 1000
df = pandas -> csv 
a = []

for i in df:
    StructField(i,StringType() , True)

# %%
# df2=spark.read.format('json').option('inferSchema','true').load('/FileStore/tables/single_line.json')
df2=spark.read.format('json').option("multiline","true").load('/FileStore/tables/multi_line.json')

# df2 = spark.read.option("multiline","true").json("/FileStore/tables/multi_line.json")
# df2 = spark.read.json("/FileStore/tables/single_line.json")
df2.show()
# Out:
# +--------------------+----------+--------------------+----------+---+----------+--------------------+
# |             address|  birthday|               email|first_name| id| last_name|              skills|
# +--------------------+----------+--------------------+----------+---+----------+--------------------+
# |{Guizi, China, null}|19.06.2019|acharleston0@smh....|    Ardene|  1|Charleston|[Knowledge Sharin...|
# |{Al Ḩashwah, Yeme...|27.10.2019|acoull1@newyorker...|   Alfonso|  2|     Coull|[DMPK, SR&amp;ED,...|
# |{Kafr Zībād, Pale...|27.11.2019|acaldron2@miitbei...|     Arley|  3|   Caldron|[Volunteer Manage...|
# |{Khon Kaen, Thail...|11.06.2020|  bbennie3@bbc.co.uk|    Blanch|  4|    Bennie|[Hospitality Indu...|
# |{Rockford, United...|19.06.2019|      pvain4@ovh.net|    Putnam|  5|      Vain|[eEye Retina, BC/...|
# |{Peraía, Greece, ...|14.09.2019|vkimmerling5@cdba...|    Verena|  6|Kimmerling|[Overseas Experie...|
# ...

# %%
dataframe3.write.option("header",True) \
 .csv("/FileStore/tables/zipcodes-345.csv")
